# %%
# run this in any directory 
# add -v for verbose 
# get Pillow (fork of PIL) from 
# pip before running --> 
# pip install Pillow 

# import required libraries 
import os 
import sys 
from PIL import Image 

# define a function for 
# compressing an image 
def compressMe(file, verbose = False): 
	
	# Get the path of the file 
	filepath = os.path.join(os.getcwd(), 
							file) 
	
	# open the image 
	picture = Image.open(filepath) 
	
	# Save the picture with desired quality 
	# To change the quality of image, 
	# set the quality variable at 
	# your desired level, The more 
	# the value of quality variable 
	# and lesser the compression 
	picture.save("Compressed_"+file, 
				"JPEG", 
				optimize = True, 
				quality = 50) 
	return

# Define a main function 
def main(): 
	
	verbose = False
	
	# checks for verbose flag 
	if (len(sys.argv)>1): 
		
		if (sys.argv[1].lower()=="-v"): 
			verbose = True
					
	# finds current working dir 
	cwd = os.getcwd() 

	formats = ('.jpg', '.jpeg') 
	
	# looping through all the files 
	# in a current directory 
	for file in os.listdir(cwd): 
		
		# If the file format is JPG or JPEG 
		if os.path.splitext(file)[1].lower() in formats: 
			print('compressing', file) 
			compressMe(file, verbose) 

	print("Done") 

# Driver code 
if __name__ == "__main__": 
	main()
# Out:
# compressing 20201222_125459.jpg
# compressing 20201222_125500(0).jpg
# compressing 20201222_125500(1).jpg
# compressing 20201222_125500.jpg
# compressing 20201222_125503(0).jpg
# compressing 20201222_125503.jpg
# compressing 20201222_125505.jpg
# compressing 20201222_125522(0).jpg
# compressing 20201222_125522.jpg
# compressing 20201222_125523.jpg
# compressing IMG_20201222_125651844_BURST000_COVER.jpg
# compressing IMG_20201222_125651844_BURST001.jpg
# compressing IMG_20201222_125651844_BURST002.jpg
# compressing IMG_20201222_125651844_BURST003.jpg
# compressing IMG_20201222_125651844_BURST004.jpg
# compressing IMG_20201222_125651844_BURST005.jpg
# compressing IMG_20201222_125651844_BURST006.jpg
# compressing IMG_20201222_125651844_BURST007.jpg
# compressing IMG_20201222_125651844_BURST008.jpg
# compressing IMG_20201222_125651844_BURST009.jpg
# compressing IMG_20201222_125651844_BURST010.jpg
# compressing IMG_20201222_125651844_BURST011.jpg
# compressing IMG_20201222_125651844_BURST012.jpg
# compressing IMG_20201222_125651844_BURST013.jpg
# compressing IMG_20201222_125651844_BURST014.jpg
# compressing IMG_20201222_125723272_BURST000_COVER.jpg
# compressing IMG_20201222_125723272_BURST001.jpg
# compressing IMG_20201222_125723272_BURST002.jpg
# compressing IMG_20201222_125723272_BURST003.jpg
# compressing IMG_20201222_125723272_BURST004.jpg
# compressing IMG_20201222_125723272_BURST005.jpg
# compressing IMG_20201222_125723272_BURST006.jpg
# compressing IMG_20201222_125723272_BURST007.jpg
# compressing IMG_20201222_125723272_BURST008.jpg
# compressing IMG_20201222_125723272_BURST009.jpg
# compressing IMG_20201222_125723272_BURST010.jpg
# compressing IMG_20201222_125723272_BURST011.jpg
# compressing IMG_20201222_125723272_BURST012.jpg
# compressing IMG_20201222_125723272_BURST013.jpg
# compressing IMG_20201222_125723272_BURST014.jpg
# compressing IMG_20201222_125807484_BURST000_COVER.jpg
# compressing IMG_20201222_125807484_BURST001.jpg
# compressing IMG_20201222_125807484_BURST002.jpg
# compressing IMG_20201222_125807484_BURST003.jpg
# compressing IMG_20201222_125807484_BURST004.jpg
# compressing IMG_20201222_125807484_BURST005.jpg
# compressing IMG_20201222_125807484_BURST006.jpg
# compressing IMG_20201222_125807484_BURST007.jpg
# compressing IMG_20201222_125807484_BURST008.jpg
# compressing IMG_20201222_125807484_BURST009.jpg
# compressing IMG_20201222_125807484_BURST010.jpg
# compressing IMG_20201222_125807484_BURST011.jpg
# compressing IMG_20201222_125807484_BURST012.jpg
# compressing IMG_20201222_125807484_BURST013.jpg
# compressing IMG_20201222_125807484_BURST014.jpg
# Done
